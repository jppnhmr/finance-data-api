# %%
import src.database as db
import src.analysis as anls

pir_datas = anls.get_pir_datas()
idx_datas = anls.get_idx_datas()

# %%
anls.plot_multi_data(pir_datas, f'Policy Interest Rates US & UK', 'Policy Interest Rate', '%')

# %%
# Plot two lines
anls.plot_multi_data(idx_datas, 'Global Index\'s', 'Index', '')

# %%
anls.plot_interest_against_index(pir_datas, idx_datas)

# %%
anls.analysis()
